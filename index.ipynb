# %% [markdown]
# # Import Library

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# # inisialisasi files

# %%
data = pd.read_excel('Indeks Pembangunan Manusia Menurut Kabupaten_Kota di Provinsi Jawa Barat, 2023.xlsx')
print(data.head())
# Out:
#   Kabupaten/Kota  Indeks Pembangunan Manusia
# 0          Bogor                       73.02
# 1       Sukabumi                       69.71
# 2        Cianjur                       68.18
# 3        Bandung                       74.03
# 4          Garut                       69.22

# %%
data.isnull().sum()
data = data.dropna()
print(data.isnull().sum())
# Out:
# Kabupaten/Kota                0
# Indeks Pembangunan Manusia    0
# dtype: int64

# %%
print(data)
# Out:
#       Kabupaten/Kota  Indeks Pembangunan Manusia
# 0              Bogor                       73.02
# 1           Sukabumi                       69.71
# 2            Cianjur                       68.18
# 3            Bandung                       74.03
# 4              Garut                       69.22
# 5        Tasikmalaya                       69.38
# 6             Ciamis                       73.12
# 7           Kuningan                       70.99
# 8            Cirebon                       71.81
# 9         Majalengka                       70.76
# 10          Sumedang                       74.02
# 11         Indramayu                       70.19
# 12            Subang                       71.42
# 13        Purwakarta                       73.43
# 14          Karawang                       73.25
# 15            Bekasi                       76.13
# 16     Bandung Barat                       70.33
# 17       Pangandaran                       70.57
# ...
